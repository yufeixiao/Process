# %% [markdown]
# # API demo

# %%
import time
import numpy as np
import matplotlib.pyplot as plt, seaborn as sns
from sklearn.neighbors import KDTree
import networkx as nx
seed = time.time_ns() #record seed
seed = np.clip(seed, 0, 2**32-1)
print("random seed", seed)
np.random.seed(seed)
# Out:
# random seed 4294967295

# %% [markdown]
# ### 1. choose a model from the model space

# %%
#set model params
sim = Simulation(N=100,tau=tau,k=3, noise=1,simtime=60)
#run!
params,outData = sim.run()
# Out:
# {'N': 100, 'size': 100, 'simtime': 60, 'tau': 0.5, 'k': 3, 'outtime': 1.0, 'speed': 1.0, 'noise': 1, 'dt': 0.05, 'steps': 1200, 'sigma_dt': 4.47213595499958, 'outstep': 20}

# %% [markdown]
# ### 2. visualize and analyze outputs

# %%
networkdashboard(params,outData)

# %%
timespace(params, outData)

# %%
orderplot(params, outData)

# %%
noisephase(sim)
# Out:
# /Users/yufeixiao/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
